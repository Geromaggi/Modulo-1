# %% [markdown]
# # Práctica Clase 7

# %% [markdown]
# 1) Diseñar una clase que permita trabajar con un árbol binario y que contenga los métodos:<br>
#     * insertaVal: para insertar un dato<br>
#     * buscaVal: que devuelva True o False si existe o no un dato<br>
#     * verVal: que imprima por pantalla los valores del árbol<br>
#
# Nota: Se puede utilizar la recursividad

# %%
class Nodo():
    def __init__(self, dato):
        self.dato = dato
        self.izq = None
        self.der = None

# %%
class Arbol():
    def __init__(self):
        self.raiz = None

    def insertaVal(self, dato):
        n = Nodo(dato)
        if (self.raiz == None):
            self.raiz = n
        else:
            puntero = self.raiz
            if (puntero.izq == None):
                puntero.izq = n
            elif (puntero.der == None):
                puntero.der = n
    
    def buscaVal(self,valor): #creamos el nodo y nos fijamos si el dato existe o no.  
        if valor < self.dato:
            if self.izq == None:
                return False
            return self.izq.buscaVal(valor)
        elif valor > self.dato:
            if self.der == None:
                return False
            return self.der.buscaVal(valor)
        else:
            return True

    def verVal(self):
        if self.der:
            self.der.verVAl()
        print(self.dato)
        if self.izq:
            self.izq.verVal()

# %%
a = Arbol()

# %%
a.insertaVal(2)
a.insertaVal(6)
a.insertaVal(1)
a.insertaVal(10)

# %%
a.buscaVal(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/gero/Escritorio/HENRY/M1/Clase 07/Homework_07.ipynb Celda 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/gero/Escritorio/HENRY/M1/Clase%2007/Homework_07.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> a.buscaVal(5)
#
# /home/gero/Escritorio/HENRY/M1/Clase 07/Homework_07.ipynb Celda 7 in Arbol.buscaVal(self, valor)
#      <a href='vscode-notebook-cell:/home/gero/Escritorio/HENRY/M1/Clase%2007/Homework_07.ipynb#W6sZmlsZQ%3D%3D?line=15'>16</a> def buscaVal(self,valor): #creamos el nodo y nos fijamos si el dato existe o no.
# ---> <a href='vscode-notebook-cell:/home/gero/Escritorio/HENRY/M1/Clase%2007/Homework_07.ipynb#W6sZmlsZQ%3D%3D?line=16'>17</a>     if valor < self.dato:
#      <a href='vscode-notebook-cell:/home/gero/Escritorio/HENRY/M1/Clase%2007/Homework_07.ipynb#W6sZmlsZQ%3D%3D?line=17'>18</a>         if self.izq == None:
#      <a href='vscode-notebook-cell:/home/gero/Escritorio/HENRY/M1/Clase%2007/Homework_07.ipynb#W6sZmlsZQ%3D%3D?line=18'>19</a>             return False
#
# AttributeError: 'Arbol' object has no attribute 'dato'

# %%
a.verVal()
# Out:
# el valor del arbol es: None
