# %% [markdown]
# # Práctica Clase 5

# %% [markdown]
# 1) Implementar un juego, que consista en apilar números enteros del 1 al 20, de forma aleatoria, para lo cual debe usarse una estructura de Pila.
# Luego, el usuario debe elegir un número de veces en que se va a quitar elementos de la pila, los cuales, sumados entre sí, no deben superar el valor de 50.
# El usuario pierde si la suma supera ese valor. Si no lo supera, gana, pero su calificación será 10 menos el número elementos que falten quitar para todavía no superar 50.
# El programa debe informar si perdió, y si ganó, con qué calificación lo hizo.
#
# Consideraciones:<br>
# a. Se puede usar la función input() para obtener una entrada de teclado.<br>
# b. Se puede usar la el modulo random para obtener valores aleatorios.

# %%
import random

class EstructuraPila:
   #crea la lista aleatoria
   def __init__(self):
       self.__list = random.sample(range(21),20)
   # Agregar un elemento a la Pila
   def push(self, item):
       self.__list.append(item)
       print(self.__list)
   # Quitar un elemento de la Pila
   def pop(self):
       return self.__list.pop()
   '''def jugar (self,item):
       item = input()
       lista_nueva = []
       elementos_eliminados = []
       for i in range (1,item):
            lista_nueva = self.__list.pop()
            elementos_eliminados = elementos_eliminados.append(self.__list.pop())
       if sum(elementos_eliminados) < 50:
            print('Has perdido.')
       else:
            '''

# %%
class JuegoCartas:
    def __init__(self):
        self.__numero_elegido = int(input("Ingrese un numero: "))
    def juego(self):
        #creacion de lista de numeros enteros aleatorios.
        numeros_aleatorios = random.sample(range(21),20)
        #creacion de list de numeros que SACAMOS.
        numeros_sacados = []
        #agregamos en una lista la cantidad de numeros elegidos
        for i in range (0,self.__numero_elegio):
            numeros_sacados.append(i)
        #sumaos cuanto da la lista de los elementos sacados
        suma_sacados = sum(numeros_sacados)
        #verificamos si el usuario gano o no.
        if suma_sacados > 50:
            print("la suma de las cartas que elegio es de:",suma_sacados,'. Has perdido, suerte la proxima!')
        else: 
            cantidad_restante = 50 - suma_sacados
            rango_final = self.__numero_elegido - cantidad_restante

            lista_final = []
            for j in range (self.__numero_elegido, rango_final):
                lista_final.append(j)
                numeros_sacados.append(j)
            
            suma_final = sum(lista_final)

            print('Usted ha ganado con un total de:',suma_final)
        
nuevo_juego = JuegoCartas()
nuevo_juego.juego()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/gero/Escritorio/HENRY/M1/Clase 05/Homework_05.ipynb Celda 4 in <cell line: 30>()
#      <a href='vscode-notebook-cell:/home/gero/Escritorio/HENRY/M1/Clase%2005/Homework_05.ipynb#X11sZmlsZQ%3D%3D?line=25'>26</a>             suma_final = sum(lista_final)
#      <a href='vscode-notebook-cell:/home/gero/Escritorio/HENRY/M1/Clase%2005/Homework_05.ipynb#X11sZmlsZQ%3D%3D?line=27'>28</a>             print('Usted ha ganado con un total de:',suma_final)
# ---> <a href='vscode-notebook-cell:/home/gero/Escritorio/HENRY/M1/Clase%2005/Homework_05.ipynb#X11sZmlsZQ%3D%3D?line=29'>30</a> nuevo_juego = JuegoCartas()
#      <a href='vscode-notebook-cell:/home/gero/Escritorio/HENRY/M1/Clase%2005/Homework_05.ipynb#X11sZmlsZQ%3D%3D?line=30'>31</a> nuevo_juego.juego()
#
# /home/gero/Escritorio/HENRY/M1/Clase 05/Homework_05.ipynb Celda 4 in JuegoCartas.__init__(self)
#       <a href='vscode-notebook-cell:/home/gero/Escritorio/HENRY/M1/Clase%2005/Homework_05.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> def __init__(self):
# ----> <a href='vscode-notebook-cell:/home/gero/Escritorio/HENRY/M1/Clase%2005/Homework_05.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a>     self.__numero_elegido = int(input("Ingrese un numero: "))
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# 2) Implementar un juego donde constas de 2 jarras, de capacidad 5 y 3 litros respectivamente, y debes colocar 4 litros en la jarra de 5L.
# Las opciones posibles son:
# * Llenar la jarra de 3 litros
# * Llenar la jarra de 5 litros
# * Vaciar la jarra de 3 litros
# * Vaciar la jarra de 5 litros
# * Verter el contenido de la jarra de 3 litros en la de 5 litros
# * Verter el contenido de la jarra de 5 litros en la de 3 litros
