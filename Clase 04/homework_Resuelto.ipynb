# %% [markdown]
# resolucion ejercicio de los hospitales

# %%
import numpy as np
import pandas as pd

# %%
df_hospitales = pd.read_csv('hospitales2.csv',sep=',',decimal='.')

# %%
df_hospitales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 20 columns):
# WKT           36 non-null object
# ID            36 non-null float64
# NOMBRE        36 non-null object
# NOM_MAP       36 non-null object
# OBJETO        36 non-null object
# CALLE         36 non-null object
# ALTURA        36 non-null int64
# DOM_NORMA     36 non-null object
# DOM_GEO       36 non-null object
# TELEFONO      36 non-null object
# GUARDIA       34 non-null object
# FAX           35 non-null object
# WEB           13 non-null object
# COD_POSTAL    36 non-null object
# TIPO          36 non-null object
# TIPO_ESPEC    35 non-null object
# MOD_AT_1      35 non-null object
# MOD_AT_2      35 non-null object
# DEPEND_ADM    36 non-null object
# DIRECTOR      36 non-null object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 5.8+ KB

# %%
df_hospitales.describe()
# Out:
#               ID       ALTURA
# count  36.000000    36.000000
# mean   18.500000  2074.055556
# std    10.535654  1394.349453
# min     1.000000    15.000000
# 25%     9.750000   924.750000
# 50%    18.500000  2041.000000
# 75%    27.250000  2776.250000
# max    36.000000  5044.000000

# %%
df_hospitales.columns
# Out:
# Index(['WKT', 'ID', 'NOMBRE', 'NOM_MAP', 'OBJETO', 'CALLE', 'ALTURA',
#        'DOM_NORMA', 'DOM_GEO', 'TELEFONO', 'GUARDIA', 'FAX', 'WEB',
#        'COD_POSTAL', 'TIPO', 'TIPO_ESPEC', 'MOD_AT_1', 'MOD_AT_2',
#        'DEPEND_ADM', 'DIRECTOR'],
#       dtype='object')

# %%
df_hospitales.shape
# Out:
# (36, 20)

# %%
df_hospitales.head(5)
# Out:
#                                            WKT   ID  \
# 0  POINT (-58.3775508488443 -34.6288473603881)  1.0
# 1  POINT (-58.4120700769456 -34.5941919726393)  2.0
# 2  POINT (-58.4027276547828 -34.5845283357505)  4.0
# 3  POINT (-58.3851559118889 -34.6394041316484)  6.0
# 4  POINT (-58.3913114406535 -34.6341535760002)  7.0
#
#                                               NOMBRE  \
# 0        HOSPITAL GENERAL DE NIÑOS PEDRO DE ELIZALDE
# 1        HOSPITAL GENERAL DE NIÑOS RICARDO GUTIERREZ
# 2  HOSPITAL DE ODONTOLOGIA DR. RAMON CARRILLO (EX...
# 3            HOSPITAL DE SALUD MENTAL BRAULIO MOYANO
# 4           HOSPITAL DE GASTROENTEROLOGIA B. UDAONDO
#
#                        NOM_MAP    OBJETO                    CALLE  ALTURA  \
# 0            HOSP. DE ELIZALDE  HOSPITAL  MANUEL A. MONTES DE OCA      40
# 1              HOSP. GUTIERREZ  HOSPITAL                    GALLO    1330
# 2  HOSP. ODONTOLOGICO CARRILLO  HOSPITAL    SANCHEZ DE BUSTAMANTE    2529
# ...

# %%
latitude_longitude = df_hospitales['WKT']
#print(latitude_longitude)
adress = df_hospitales['DOM_NORMA']
label = df_hospitales['NOMBRE']

# %%
info_imp_hospitales = {'latitud y longitud' : latitude_longitude,
                        'direccion': adress,
                        'nombre' : label}

# %%
df_hospitales2 = pd.DataFrame(info_imp_hospitales)

# %%
print(df_hospitales2)
# Out:
#                              latitud y longitud  \
# 0   POINT (-58.3775508488443 -34.6288473603881)
# 1   POINT (-58.4120700769456 -34.5941919726393)
# 2   POINT (-58.4027276547828 -34.5845283357505)
# 3   POINT (-58.3851559118889 -34.6394041316484)
# 4   POINT (-58.3913114406535 -34.6341535760002)
# 5   POINT (-58.4349433479819 -34.6084721257413)
# 6   POINT (-58.3758433488021 -34.6302112044495)
# 7   POINT (-58.3823284509488 -34.6357022351559)
# 8   POINT (-58.3821283746958 -34.6364350546569)
# 9   POINT (-58.3601201271455 -34.6388917320834)
# 10  POINT (-58.4409882382439 -34.5538963316473)
# 11   POINT (-58.4027506275377 -34.634856308415)
# 12  POINT (-58.4601855775528 -34.6054342750207)
# 13  POINT (-58.4276597542837 -34.6146348348429)
# 14  POINT (-58.4332484381295 -34.6070507603866)
# 15  POINT (-58.4323966950244 -34.6255031952483)
# 16  POINT (-58.3940641604746 -34.6227125075124)
# 17  POINT (-58.5021449222222 -34.6179817540591)
# ...

# %%
df_hospitales2.to_csv('Hospitales2.csv',sep=',',index=False)
#,columns=True,index=True)
